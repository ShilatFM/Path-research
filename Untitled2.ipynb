# %%
# %pylab inline
import pandas as pd
dp = pd.read_pickle("data/to_pickle.pk1.xz")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dp
x_max = max(dp.x)
y_max = max(dp.y)
(x_max, y_max)


len(dp[(dp.x == 121) & (dp.y == 251)])


dplicate_bool = dp.duplicated(subset = ['x','y'], keep = 'first')
len(dp.loc[dplicate_bool == False])
# Out:
# 104910

# %%
dp2 = dp.groupby(['x','y']).size().sort_values() 
dp2.name = "v"
dp2 = dp2.reset_index()
dp2 = dp2[dp2.v <= 10]
im = imread("C:\EXELLENTIM\paths0.png")
ma = ones(im.shape)
ma
ma[dp2.y, dp2.x] = 0
imshow(im)
imshow(ma, alpha = 0.5)

# %%
dp
dp1 = dp.groupby(['obj', 'filename']).size()
len(dp1)
# Out:
# 24599

# %%
dp
mob = dp[(dp.seq == max(dp.seq))].[mob.obj,mob.filename]
mob
# Out:
#   File "<ipython-input-64-576e9ba11026>", line 2
#     mob = dp[(dp.seq == max(dp.seq))].[mob.obj,mob.filename]
#                                       ^
# SyntaxError: invalid syntax
